# %%
#soal 6

my_dict = {}
my_dict[(1,2,4)] = 8
my_dict[(4,2,1)] = 10
my_dict[(1,2)] = 12

sum = 0
for k in my_dict:
    sum += my_dict[k]

print (sum)
print(my_dict)

#jawab B 30   
#     {(1, 2, 4): 8, (4, 2, 1): 10, (1, 2): 12}
# Out:
# 30
# {(1, 2, 4): 8, (4, 2, 1): 10, (1, 2): 12}
