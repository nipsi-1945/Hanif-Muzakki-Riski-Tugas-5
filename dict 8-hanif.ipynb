# %%
#soal 7

dict = {'c': 97, 'a': 96, 'b': 98}

for _ in sorted(dict):
    print (dict[_])

#jawab D Type Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       9 crates['box'] = box
#      10 crates['jars'] = jars
# ---> 11 print(len(crates[box]))
#
# TypeError: unhashable type: 'dict'
