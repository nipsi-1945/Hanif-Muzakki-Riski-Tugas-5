# %%
#soal 2

a = {'a':1,'b':2,'c':3}
print (a['a','b'])


#jawab A (key error)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 #soal 2
#       3 a = {'a':1,'b':2,'c':3}
# ----> 4 print (a['a','b'])
#
# KeyError: ('a', 'b')
