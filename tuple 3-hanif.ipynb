# %%
# Q-3. What will be the output of the following code block?

init_tuple_a = '1', '2'
init_tuple_b = ('3', '4')

print (init_tuple_a + init_tuple_b)
#jawab B.  (‘1’, ‘2’, ‘3’, ‘4’)
# Out:
# ('1', '2', '3', '4')
